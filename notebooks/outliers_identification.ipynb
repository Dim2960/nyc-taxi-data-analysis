# %% [markdown]
# # identification des valeurs illogique et des outliers

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
file_path = "../data_clean/taxi_trip_2016-clean1.parquet"

df = pd.read_parquet(file_path)

# %% [markdown]
# ## 1- Indentification des données illogiques

# %%
# Marquer les erreur logique de < à 0 ou <= 0 anormal
df["data_ok_flag"] = np.where(
    (df['trip_distance'] > 0) &
    (df['trip_time'] > 0) &
    (df['fare_amount'] >= 0) &
    (df['extra'] >= 0) &
    (df['mta_tax'] >= 0) &
    (df['tip_amount'] >= 0) &
    (df['tolls_amount'] >= 0) &
    (df['improvement_surcharge'] >= 0) &
    (df['total_amount'] > 0), True, False) # "data_ok"->True, "data_nok"-> False

# %%
df.head()
# Out:
#    id  VendorID        date tpep_pickup_datetime  pickup_hour  \
# 0   1         2  2016-01-01           2016-01-01            0
# 1   2         2  2016-01-01           2016-01-01            0
# 2   3         2  2016-01-01           2016-01-01            0
# 3   4         2  2016-01-01           2016-01-01            0
# 4   5         2  2016-01-01           2016-01-01            0
#
#    passenger_count  trip_distance  trip_time  RatecodeID store_and_fwd_flag  \
# 0                2           1.10        0.0           1                  N
# 1                5           4.90        0.0           1                  N
# 2                1          10.54        0.0           1                  N
# 3                1           4.75        0.0           1                  N
# 4                3           1.76        0.0           1                  N
#
#    ...  pickup_neighborhood_id  dropoff_neighborhood_id  fare_amount  extra  \
# 0  ...                     1.0                      1.0          7.5    0.5
# 1  ...                     2.0                     26.0         18.0    0.5
# 2  ...                     3.0                      9.0         33.0    0.5
# 3  ...                     4.0                   8973.0         16.5    0.0
# 4  ...                     5.0                     29.0          8.0    0.0
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5         0.0           0.0                    0.3           8.8
# 1      0.5         0.0           0.0                    0.3          19.3
# 2      0.5         0.0           0.0                    0.3          34.3
# 3      0.5         0.0           0.0                    0.3          17.3
# 4      0.5         0.0           0.0                    0.3           8.8
#
#    data_ok_flag
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2- Identifications des outliers sur trip distance et trip_time

# %%
# Définir les variables explicatives (X) et la variable cible (Y)
X_columns = ["trip_time", "trip_distance"]  
Y_column = "fare_amount"

# %%
# trie des données avant mise en place du model
df_trie = df[df["data_ok_flag"] == True]

# %%
# Filtrer les lignes avec des valeurs nulles (nécessaire pour statsmodels)
df_trie = df_trie.dropna(subset=[Y_column] + X_columns) # type: ignore

# %%
# Ajouter une constante pour la régression (intercept)
X = sm.add_constant(df_trie[X_columns])  
y = df_trie[Y_column]

# %%
# Modèle de régression quantile (quantile = 0.5 → médiane)
quantile = 0.5  # Changer à 0.25 ou 0.75 pour des bornes plus strictes
model = sm.QuantReg(y, X).fit(q=quantile)

# %%
# Prédiction du Y attendu
df_trie["Y_Pred"] = model.predict(X)

# %%
# Calcul des résidus (erreur absolue entre Y et Y_Pred)
df_trie["Residual"] = np.abs(df_trie[Y_column] - df_trie["Y_Pred"])

# Calcul des quantiles des résidus
Q1 = df_trie["Residual"].quantile(0.25)
Q3 = df_trie["Residual"].quantile(0.75)
IQR = Q3 - Q1

# Seuil pour détecter les outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Marquer les outliers
df_trie["Outlier_Flag"] = np.where((df_trie["Residual"] > upper_bound), True, False) # "Outlier"->True, "Normal"-> False

# %%
df_trie["Outlier_Flag"].describe()
# Out:
# count     34285260
# unique           2
# top          False
# freq      29542943
# Name: Outlier_Flag, dtype: object

# %%
# suppression des colonne de construction
df_trie.drop(columns=["Y_Pred"], inplace=True)
df_trie.drop(columns=["Residual"], inplace=True)

# %%
df_trie.head()
# Out:
#    id  VendorID        date tpep_pickup_datetime  pickup_hour  \
# 5   6         2  2016-01-01           2016-01-01            0
# 6   7         2  2016-01-01           2016-01-01            0
# 7   8         1  2016-01-01           2016-01-01            0
# 8   9         1  2016-01-01           2016-01-01            0
# 9  10         2  2016-01-01           2016-01-01            0
#
#    passenger_count  trip_distance  trip_time  RatecodeID store_and_fwd_flag  \
# 5                2           5.52     1110.0           1                  N
# 6                2           7.45     1605.0           1                  N
# 7                1           1.20      714.0           1                  N
# 8                1           6.00      672.0           1                  N
# 9                1           3.21      666.0           1                  N
#
#    ...  dropoff_neighborhood_id  fare_amount  extra  mta_tax  tip_amount  \
# 5  ...                    549.0         19.0    0.5      0.5         0.0
# 6  ...                     16.0         26.0    0.5      0.5         0.0
# 7  ...                     29.0          9.0    0.5      0.5         0.0
# 8  ...                  12149.0         18.0    0.5      0.5         0.0
# 9  ...                    209.0         11.5    0.5      0.5         0.0
#
#    tolls_amount  improvement_surcharge  total_amount  data_ok_flag  \
# 5           0.0                    0.3          20.3          True
# 6           0.0                    0.3          27.3          True
# 7           0.0                    0.3          10.3          True
# 8           0.0                    0.3          19.3          True
# 9           0.0                    0.3          12.8          True
#
#    Outlier_Flag
# 5          True
# 6          True
# 7         False
# 8          True
# 9         False
#
# [5 rows x 22 columns]

# %%
# merge de df et df_trie
df = pd.merge(df, df_trie[["id","Outlier_Flag"]], how="left", left_on="id", right_on="id")

df["Outlier_Flag"] = df["Outlier_Flag"].fillna(True)
# Out:
# C:\Users\dimle\AppData\Local\Temp\ipykernel_31708\974689458.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Outlier_Flag"] = df["Outlier_Flag"].fillna(True)

# %%
df.head(20)
# Out:
#     id  VendorID        date tpep_pickup_datetime  pickup_hour  \
# 0    1         2  2016-01-01           2016-01-01            0
# 1    2         2  2016-01-01           2016-01-01            0
# 2    3         2  2016-01-01           2016-01-01            0
# 3    4         2  2016-01-01           2016-01-01            0
# 4    5         2  2016-01-01           2016-01-01            0
# 5    6         2  2016-01-01           2016-01-01            0
# 6    7         2  2016-01-01           2016-01-01            0
# 7    8         1  2016-01-01           2016-01-01            0
# 8    9         1  2016-01-01           2016-01-01            0
# 9   10         2  2016-01-01           2016-01-01            0
# 10  11         2  2016-01-01           2016-01-01            0
# 11  12         2  2016-01-01           2016-01-01            0
# 12  13         2  2016-01-01           2016-01-01            0
# 13  14         1  2016-01-01           2016-01-01            0
# 14  15         1  2016-01-01           2016-01-01            0
# 15  16         2  2016-01-01           2016-01-01            0
# 16  17         2  2016-01-01           2016-01-01            0
# 17  18         1  2016-01-01           2016-01-01            0
# 18  19         2  2016-01-01           2016-01-01            0
# 19  20         1  2016-01-01           2016-01-01            0
#
#     passenger_count  trip_distance  trip_time  RatecodeID store_and_fwd_flag  \
# 0                 2           1.10        0.0           1                  N
# 1                 5           4.90        0.0           1                  N
# 2                 1          10.54        0.0           1                  N
# 3                 1           4.75        0.0           1                  N
# 4                 3           1.76        0.0           1                  N
# 5                 2           5.52     1110.0           1                  N
# 6                 2           7.45     1605.0           1                  N
# 7                 1           1.20      714.0           1                  N
# 8                 1           6.00      672.0           1                  N
# 9                 1           3.21      666.0           1                  N
# 10                1           0.79      376.0           1                  N
# 11                6           2.43      946.0           1                  N
# 12                4           0.01        8.0           1                  N
# 13                1           3.70      868.0           1                  N
# 14                2           2.20      862.0           1                  N
# 15                1           0.54      432.0           1                  N
# 16                1           1.92      429.0           1                  N
# 17                1           1.70      278.0           1                  Y
# 18                1           1.38      428.0           1                  N
# 19                2           4.90     1228.0           1                  N
#
#     ...  dropoff_neighborhood_id  fare_amount  extra  mta_tax  tip_amount  \
# 0   ...                      1.0          7.5    0.5      0.5        0.00
# 1   ...                     26.0         18.0    0.5      0.5        0.00
# 2   ...                      9.0         33.0    0.5      0.5        0.00
# 3   ...                   8973.0         16.5    0.0      0.5        0.00
# 4   ...                     29.0          8.0    0.0      0.5        0.00
# 5   ...                    549.0         19.0    0.5      0.5        0.00
# 6   ...                     16.0         26.0    0.5      0.5        0.00
# 7   ...                     29.0          9.0    0.5      0.5        0.00
# 8   ...                  12149.0         18.0    0.5      0.5        0.00
# 9   ...                    209.0         11.5    0.5      0.5        0.00
# 10  ...                     54.0          6.0    0.5      0.5        0.00
# 11  ...                     11.0         12.0    0.5      0.5        3.99
# 12  ...                      4.0          2.5    0.5      0.5        0.00
# 13  ...                     91.0         14.0    0.5      0.5        3.05
# 14  ...                     24.0         11.0    0.5      0.5        1.50
# 15  ...                     48.0          6.0    0.5      0.5        0.00
# 16  ...                     16.0          7.5    0.5      0.5        0.00
# 17  ...                     16.0          7.0    0.5      0.5        1.65
# 18  ...                      2.0          7.0    0.5      0.5        1.66
# 19  ...                      4.0         19.0    0.5      0.5        4.06
#
#     tolls_amount  improvement_surcharge  total_amount  data_ok_flag  \
# 0            0.0                    0.3          8.80         False
# 1            0.0                    0.3         19.30         False
# 2            0.0                    0.3         34.30         False
# 3            0.0                    0.3         17.30         False
# 4            0.0                    0.3          8.80         False
# 5            0.0                    0.3         20.30          True
# 6            0.0                    0.3         27.30          True
# 7            0.0                    0.3         10.30          True
# 8            0.0                    0.3         19.30          True
# 9            0.0                    0.3         12.80          True
# 10           0.0                    0.3          7.30          True
# 11           0.0                    0.3         17.29          True
# 12           0.0                    0.3          3.80          True
# 13           0.0                    0.3         18.35          True
# 14           0.0                    0.3         13.80          True
# 15           0.0                    0.3          7.30          True
# 16           0.0                    0.3          8.80          True
# 17           0.0                    0.3          9.95          True
# 18           0.0                    0.3          9.96          True
# 19           0.0                    0.3         24.36          True
#
#     Outlier_Flag
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7          False
# 8           True
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19          True
#
# [20 rows x 22 columns]

# %% [markdown]
# ## 3- Enregistrement des données en parquet

# %%
df.to_parquet("../data_clean/taxi_trip_2016-clean.parquet", index=False)
